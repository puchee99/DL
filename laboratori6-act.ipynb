# %% [markdown]
# # CNN Transfer Learning

# %% [markdown]
# In this notebook we will learn how to finetune a modern
# CNN architecture from the [`torchvision models`](https://pytorch.org/docs/stable/torchvision/models.html), which has been pretrained on the [Imagenet dataset](http://www.image-net.org/). The [`torchvision models`](https://pytorch.org/docs/stable/torchvision/models.html) module implements lots of popular CNN models such as: AlexNet, VGG, ResNet, DenseNet, GoogLeNet, etc.
#
#
# *Credit: This notebook has been adapted from the official [PyTorch finetuning tutorial](https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html).*
#
# The Imagenet dataset has 1000 classes and millions of images. Training a ResNet-50 model on ImageNet-1k with a single GPU takes several days. The key idea of transfer learning is to reuse the knowledge learned in one task to solve a different task. Transfer learning is specially useful when we do not have lots of training data for the new task nad/or when we want to speed up the training of the new model.
#
# For the target task we will use the [hymenoptera_data dataset](https://download.pytorch.org/tutorial/hymenoptera_data.zip), which consists in only **two classes** ('ants' and 'bees') and only around **one hundred training examples** for each class.

# %% [markdown]
# <table>
#     <tr>
#         <td style="text-align:center">bee</td><td style="text-align:center">ant</td>
#     </tr>
#     <tr>
#         <td><img src="......"></td>
#         <td><img src="......"></td>
#     </tr>
# </table>

# %% [markdown]
# We will perform two types of transfer learning: finetuning and feature extraction. In **finetuning**, we start with a pretrained model and update *all* of the model’s parameters for a new task. In **feature extraction**,
# we start with a pretrained model and only update the final layer weights.
#
# In general both transfer learning methods follow the same few steps:
#
# -  Initialize the pretrained model
# -  Reshape the final layer(s) to have the same number of outputs as the number of classes in the new dataset
# -  Define for the optimization algorithm which parameters we want to update during training
# -  Run the training step

# %% [markdown]
# ### Load the necessary libraries
#
# The following code imports the packages needed for this example.

# %%
from __future__ import print_function 
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms

import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)

# %matplotlib inline


# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# PyTorch Version:  1.8.1+cu101
# Torchvision Version:  0.9.1+cu101

# %% [markdown]
# ### Prepare the dataset
#
# The *hymenoptera_data* dataset is structured such that we can use the [`ImageFolder`](https://pytorch.org/docs/stable/torchvision/datasets.html#torchvision.datasets.ImageFolder) dataset class. Since we are reusing a pretrained model we must initialize the data transforms as in the original model. See [here](https://pytorch.org/vision/0.8/models.html) for more details.

# %%
# download the dataset
url = 'https://download.pytorch.org/tutorial/hymenoptera_data.zip'
datasets.utils.download_and_extract_archive(url, './data')

data_dir = "./data/hymenoptera_data/"

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}
# Out:
# Downloading https://download.pytorch.org/tutorial/hymenoptera_data.zip to ./data/hymenoptera_data.zip
# HBox(children=(FloatProgress(value=0.0, max=47286322.0), HTML(value='')))
# Extracting ./data/hymenoptera_data.zip to ./data
# Initializing Datasets and Dataloaders...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ### Visualize some images

# %%
import matplotlib.image as mpimg

# show some images
plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    idx = np.random.randint(0,len(image_datasets['train'].samples))
    image = mpimg.imread(image_datasets['train'].samples[idx][0])
    plt.imshow(image)
    plt.axis('off');

# %% [markdown]
# ### EXERCISE 1
#
# Since we have very little training data it makes sense to use some data augmentation for training.
#
# Add some data augmentation to the training data transforms.

# %%
# ResNet input size
input_size = (224,224)   #dimensión de las imágenes

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}
# Out:
# Initializing Datasets and Dataloaders...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## Define the training helper function
#
# The ``train_model`` function handles the training and validation of a
# given model. As input, it takes a PyTorch model, a dictionary of
# dataloaders, a loss function, an optimizer, and a specified number of epochs
# to train and validate for.

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    acc_history = {"train": [], "val": []}
    losses = {"train": [], "val": []}

    # we will keep a copy of the best weights so far according to validation accuracy
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    losses[phase].append(loss)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            
            acc_history[phase].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, acc_history, losses

# %% [markdown]
# ## Initialize the ResNet model
#
# We will use the Resnet18 model (the smaller one), as our dataset is small and only has two classes. When we print the model, we see that the last layer is a fully connected layer as shown below:
#
#
#    `(fc): Linear(in_features=512, out_features=1000, bias=True)`

# %%
def initialize_model():
    # Resnet18  
    model = models.resnet18()
    
    input_size = 224 # default input size for ResNet

    return model, input_size



# Initialize the model
model, input_size = initialize_model()

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# ### EXERCISE 2
#
# Modify the function `initialize_model` so it reinitializes ``model.fc`` to be a Linear layer with 512 input features and 2 output features.

# %%
def initialize_model(num_classes):
    model = models.resnet18()
    
    model.fc = nn.Linear(512, 2)  #linear layer amb 512 input features i 2 output features (2 classes)
    
    input_size = 224  # default input size for ResNet
        
    return model, input_size


# Number of classes in the dataset
num_classes = 2

# Initialize the model
model, input_size = initialize_model(num_classes)

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ### Run Training and Validation Step
#
# Let's start by training the model from scratch. What do you think will happen?

# %%
# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 15

optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.9113 Acc: 0.5697
# val Loss: 0.8960 Acc: 0.6144
#
# Epoch 1/14
# ----------
# train Loss: 0.7217 Acc: 0.5820
# val Loss: 0.7824 Acc: 0.6536
#
# Epoch 2/14
# ----------
# train Loss: 0.7305 Acc: 0.5533
# val Loss: 0.6595 Acc: 0.5817
#
# Epoch 3/14
# ----------
# train Loss: 0.6430 Acc: 0.6393
# val Loss: 0.6868 Acc: 0.5817
#
# Epoch 4/14
# ----------
# train Loss: 0.6353 Acc: 0.6270
# val Loss: 0.7937 Acc: 0.6405
#
# Epoch 5/14
# ----------
# train Loss: 0.6966 Acc: 0.5779
# val Loss: 0.8351 Acc: 0.6993
#
# Epoch 6/14
# ----------
# train Loss: 0.7118 Acc: 0.5943
# val Loss: 0.8395 Acc: 0.6078
#
# Epoch 7/14
# ----------
# train Loss: 0.6537 Acc: 0.6311
# val Loss: 0.7286 Acc: 0.6078
#
# Epoch 8/14
# ----------
# train Loss: 0.6224 Acc: 0.6680
# val Loss: 0.6425 Acc: 0.6667
#
# Epoch 9/14
# ----------
# train Loss: 0.5929 Acc: 0.6844
# val Loss: 0.9875 Acc: 0.5621
#
# Epoch 10/14
# ----------
# train Loss: 0.5914 Acc: 0.6680
# val Loss: 0.6856 Acc: 0.6797
#
# Epoch 11/14
# ----------
# train Loss: 0.5564 Acc: 0.7172
# val Loss: 0.5644 Acc: 0.7124
#
# Epoch 12/14
# ----------
# train Loss: 0.5657 Acc: 0.7008
# val Loss: 0.5932 Acc: 0.7190
#
# Epoch 13/14
# ----------
# train Loss: 0.5536 Acc: 0.6967
# val Loss: 0.5910 Acc: 0.7582
#
# Epoch 14/14
# ----------
# train Loss: 0.6005 Acc: 0.6844
# val Loss: 0.5598 Acc: 0.7255
#
# Training complete in 0m 50s
# Best val Acc: 0.758170

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses["train"], label="training loss")
ax1.plot(losses["val"], label="validation loss")
ax1.legend()

ax2.plot(hist["train"],label="training accuracy")
ax2.plot(hist["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# Training from scratch with only 100 examples per class does not allow the network to perform very well in this task. It reaches at most 70% accuracy, and the loss seems not descreassing anymore.

# %% [markdown]
# ## Preparing the model for finetuning and feature extraction
#
# In order to load the the pretrained weights for the ResNet model we must change a bit the function `initialize model`.

# %%
def initialize_model(num_classes):
    # Resnet18 with pretrained weights 
    model = models.resnet18(pretrained=True) # Notice we are now loading the weights of a ResNet model trained on ImageNet
    set_parameter_requires_grad(model, True) #actualitzem només els pesos de la última capa, els pesos de les altres capes ens els quedem tal i com estan
    

    model.fc = nn.Sequential(
    nn.Dropout(0.5),
    nn.Linear(512, 2))
    
    input_size = 224 #512
        
    return model, input_size


# Number of classes in the dataset
num_classes = 2

# Initialize the model
model_feature_extraction, input_size = initialize_model(num_classes)

# %% [markdown]
# Moreover, depending if we want to do finetuning (update all parameters) or if we want to do feature extraction (update only the last fully connected layer), we must specify wich parameter to update.
#
# The following helper function sets the ``.requires_grad`` attribute of the parameters in the model. This is especially useful when you want to freeze part of your model, as the parameters with ``.requires_grad=False`` will not be updated during training.

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %% [markdown]
# CAUTION: you must call this function in the correct place, otherwise you will have no learnable parameters in your model.

# %% [markdown]
# ### Create the Optimizer
#
#
# The final step for finetuning and feature extracting is to create an optimizer that only updates the
# desired parameters. Recall that after loading the pretrained model, but before reshaping, if ``feature_extract=True`` we manually set all of the parameter’s ``.requires_grad`` attributes to False. Then the reinitialized layer’s parameters have ``.requires_grad=True`` by default.

# %%
# Observe that only the fc parameters are optimized
optimizer_ft = optim.Adam(model_feature_extraction.fc.parameters(), lr=0.001) #només actualitza els paràmetres que vulguem

# %% [markdown]
# # HOMEWORK

# %% [markdown]
# A) Train the model with feature extraction for 15 epochs. This is, you must freeze all parameters except the last fully connected layer. Plot the train/val losses and accuracies. **(feature extraction = actualitzar només la última fully connected layer)**

# %%
# Send the model to GPU
model_feature_extraction = model_feature_extraction.to(device)
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 15
#optimizer_ft = optim.Adam(model.fc.parameters(), lr=0.001)


# Train and evaluate
model_feature_extraction, hist_feature_extraction, losses_feature_extraction = train_model(model_feature_extraction, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.7537 Acc: 0.5574
# val Loss: 0.4887 Acc: 0.7843
#
# Epoch 1/14
# ----------
# train Loss: 0.5350 Acc: 0.7172
# val Loss: 0.3641 Acc: 0.8758
#
# Epoch 2/14
# ----------
# train Loss: 0.4434 Acc: 0.7992
# val Loss: 0.3150 Acc: 0.8954
#
# Epoch 3/14
# ----------
# train Loss: 0.3721 Acc: 0.8320
# val Loss: 0.3092 Acc: 0.8954
#
# Epoch 4/14
# ----------
# train Loss: 0.3968 Acc: 0.8197
# val Loss: 0.2511 Acc: 0.9085
#
# Epoch 5/14
# ----------
# train Loss: 0.3524 Acc: 0.8279
# val Loss: 0.2469 Acc: 0.9085
#
# Epoch 6/14
# ----------
# train Loss: 0.3566 Acc: 0.8484
# val Loss: 0.2248 Acc: 0.9281
#
# Epoch 7/14
# ----------
# train Loss: 0.2998 Acc: 0.8770
# val Loss: 0.2708 Acc: 0.8889
#
# Epoch 8/14
# ----------
# train Loss: 0.3544 Acc: 0.8361
# val Loss: 0.2135 Acc: 0.9346
#
# Epoch 9/14
# ----------
# train Loss: 0.2353 Acc: 0.9221
# val Loss: 0.2138 Acc: 0.9346
#
# Epoch 10/14
# ----------
# train Loss: 0.3052 Acc: 0.8975
# val Loss: 0.2074 Acc: 0.9281
#
# Epoch 11/14
# ----------
# train Loss: 0.3147 Acc: 0.8648
# val Loss: 0.2230 Acc: 0.9216
#
# Epoch 12/14
# ----------
# train Loss: 0.2728 Acc: 0.8648
# val Loss: 0.2088 Acc: 0.9216
#
# Epoch 13/14
# ----------
# train Loss: 0.3246 Acc: 0.8811
# val Loss: 0.2076 Acc: 0.9216
#
# Epoch 14/14
# ----------
# train Loss: 0.2587 Acc: 0.8852
# val Loss: 0.2114 Acc: 0.9216
#
# Training complete in 0m 47s
# Best val Acc: 0.934641

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses_feature_extraction["train"], label="training loss")
ax1.plot(losses_feature_extraction["val"], label="validation loss")
ax1.legend()

ax2.plot(hist_feature_extraction["train"],label="training accuracy")
ax2.plot(hist_feature_extraction["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# B) Train the model finetuning all the parameters for 15 epochs. Plot the train/val losses and accuracies. **(finetuning = update all parameters)**

# %%
def initialize_model(num_classes):
    # Resnet18 with pretrained weights 
    model = models.resnet18(pretrained=True) # Notice we are now loading the weights of a ResNet model trained on ImageNet
    #set_parameter_requires_grad(model, True) #actualitzem només els pesos de la última capa, els pesos de les altres capes ens els quedem tal i com estan
    

    model.fc = nn.Sequential(
    nn.Dropout(0.5),
    nn.Linear(512, 2))
    
    input_size = 224 #512
        
    return model, input_size


# Number of classes in the dataset
num_classes = 2

# Initialize the model
model_finetuning, input_size = initialize_model(num_classes)

# %%
# Observe that only the fc parameters are optimized
optimizer_ft = optim.Adam(model_finetuning.parameters(), lr=0.001) #només actualitza els paràmetres que vulguem

# %%
# Send the model to GPU
model_finetuning = model_finetuning.to(device)
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 15
#optimizer_ft = optim.Adam(model.fc.parameters(), lr=0.001)


# Train and evaluate
model_finetuning, hist_finetuning, losses_finetuning = train_model(model_finetuning, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 1.1509 Acc: 0.6557
# val Loss: 10.1761 Acc: 0.5490
#
# Epoch 1/14
# ----------
# train Loss: 0.7264 Acc: 0.7090
# val Loss: 0.8236 Acc: 0.7124
#
# Epoch 2/14
# ----------
# train Loss: 0.6516 Acc: 0.7336
# val Loss: 0.7572 Acc: 0.7320
#
# Epoch 3/14
# ----------
# train Loss: 0.5006 Acc: 0.7951
# val Loss: 1.7013 Acc: 0.6667
#
# Epoch 4/14
# ----------
# train Loss: 0.4444 Acc: 0.8156
# val Loss: 0.7965 Acc: 0.7320
#
# Epoch 5/14
# ----------
# train Loss: 0.4125 Acc: 0.8156
# val Loss: 0.5208 Acc: 0.7647
#
# Epoch 6/14
# ----------
# train Loss: 0.3670 Acc: 0.8852
# val Loss: 0.6123 Acc: 0.7647
#
# Epoch 7/14
# ----------
# train Loss: 0.2580 Acc: 0.8852
# val Loss: 0.6379 Acc: 0.7516
#
# Epoch 8/14
# ----------
# train Loss: 0.3654 Acc: 0.8730
# val Loss: 0.8263 Acc: 0.6536
#
# Epoch 9/14
# ----------
# train Loss: 0.4105 Acc: 0.8279
# val Loss: 0.5734 Acc: 0.7516
#
# Epoch 10/14
# ----------
# train Loss: 0.2312 Acc: 0.8975
# val Loss: 0.7239 Acc: 0.7516
#
# Epoch 11/14
# ----------
# train Loss: 0.3390 Acc: 0.8975
# val Loss: 4.6368 Acc: 0.4641
#
# Epoch 12/14
# ----------
# train Loss: 0.2227 Acc: 0.9098
# val Loss: 0.7277 Acc: 0.7647
#
# Epoch 13/14
# ----------
# train Loss: 0.1746 Acc: 0.9262
# val Loss: 0.6522 Acc: 0.8039
#
# Epoch 14/14
# ----------
# train Loss: 0.1677 Acc: 0.9344
# val Loss: 0.8765 Acc: 0.7320
#
# Training complete in 0m 50s
# Best val Acc: 0.803922

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses_finetuning["train"], label="training loss")
ax1.plot(losses_finetuning["val"], label="validation loss")
ax1.legend()

ax2.plot(hist_finetuning["train"],label="training accuracy")
ax2.plot(hist_finetuning["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# C) Plot the  train/val losses and accuracies of all three approaches: training from scratch, finetunning, and festure extraction. To make easier visualization and comparison, use four `plt.subplots`: one for training loss, one for val loss, one for training accuracy, and one for val accuracy.
#
# **IMPORTANT: Make the plot self-explanatory: use legends and titles for each subplot, and a main title for the whole figure.**

# %%
fig, axs = plt.subplots(3, 2, figsize=(18, 10))

#scratch
axs[0, 0].plot(losses["train"], label='training loss')
axs[0, 0].plot(losses["val"], label='validation loss')
axs[0, 0].set_title('Scratch loss')
axs[0, 0].legend()

axs[0, 1].plot(hist["train"], label='training loss')
axs[0, 1].plot(hist["val"], label='validation loss')
axs[0, 1].set_title('Scratch accuracy')
axs[0, 1].legend()

#feature extraction
axs[1, 0].plot(losses_feature_extraction["train"], label='training loss')
axs[1, 0].plot(losses_feature_extraction["val"], label='validation loss')
axs[1, 0].set_title('Feature extraction loss')
axs[1, 0].legend()

axs[1, 1].plot(hist_feature_extraction['train'], label='training loss')
axs[1, 1].plot(hist_feature_extraction['val'], label='validation loss')
axs[1, 1].set_title('Feature extraction accuracy')
axs[1, 1].legend()

#finetuning
axs[2, 0].plot(losses_finetuning["train"], label='training loss')
axs[2, 0].plot(losses_finetuning["val"], label='validation loss')
axs[2, 0].set_title('Finetunning loss')
axs[2, 0].legend()

axs[2, 1].plot(hist_finetuning['train'], label='training loss')
axs[2, 1].plot(hist_finetuning['val'], label='validation loss')
axs[2, 1].set_title('Finetuning accuracy')
axs[2, 1].legend()


"""
for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
"""
# Out:
# "\nfor ax in axs.flat:\n    ax.set(xlabel='x-label', ylabel='y-label')\n\n# Hide x labels and tick labels for top plots and y ticks for right plots.\nfor ax in axs.flat:\n    ax.label_outer()\n"

# %% [markdown]
# D) Train the same model for a different dataset (MIT Scenes) using the three training strategies: from scratch, finetunning, and feature extraction.
#
# The URL of the dataset is the following:
#
# https://xnap-datasets.s3.us-east-2.amazonaws.com/MIT_scenes.zip
#
# The dataset contains scene images of 8 classes: coast, forest, highway, inside_city, mountain, open_country, street, and tallbuilding. The number of training images per class varies between 187 and 295.
#
# D.1) Visualize some of the images
#
# D.2) Train the ResNet-18 model **for 40 epochs** using the three training strategies: from scratch, finetunning, and feature extraction. Each training process should take approx. 10 minutes on colab.
#
# D.3) Plot the  train/val losses and accuracies of all of them. Again, to make easier visualization and comparison, use four `plt.subplots`: one for training loss, one for val loss, one for training accuracy, and one for val accuracy.

# %%
# download the dataset
url = 'https://xnap-datasets.s3.us-east-2.amazonaws.com/MIT_scenes.zip'
datasets.utils.download_and_extract_archive(url, './data')

data_dir = "./data/MIT_scenes/"

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}
# Out:
# Downloading https://xnap-datasets.s3.us-east-2.amazonaws.com/MIT_scenes.zip to ./data/MIT_scenes.zip
# HBox(children=(FloatProgress(value=0.0, max=127093454.0), HTML(value='')))
# Extracting ./data/MIT_scenes.zip to ./data
# Initializing Datasets and Dataloaders...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import matplotlib.image as mpimg

# show some images
plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    idx = np.random.randint(0,len(image_datasets['train'].samples))
    image = mpimg.imread(image_datasets['train'].samples[idx][0])
    plt.imshow(image)
    plt.axis('off');

# %% [markdown]
# # 1. scratch

# %%
def initialize_model(num_classes):
    # Resnet18 
    model = models.resnet18(pretrained=False)
    
    model.fc = nn.Sequential(
    nn.Dropout(0.5),
    nn.Linear(512, num_classes)
    )
    

    input_size = 224 #512
        
    return model, input_size


# Number of classes in the dataset
num_classes = 8

# Initialize the model
model, input_size = initialize_model(num_classes)

# Print the model we just instantiated
print(model)
# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40

optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=512, out_features=8, bias=True)
#   )
# )
# Epoch 0/39
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 1.8066 Acc: 0.3509
# val Loss: 1.5901 Acc: 0.4498
#
# Epoch 1/39
# ----------
# train Loss: 1.3279 Acc: 0.5141
# val Loss: 0.9333 Acc: 0.6468
#
# Epoch 2/39
# ----------
# train Loss: 1.1393 Acc: 0.5991
# val Loss: 0.9533 Acc: 0.6592
#
# Epoch 3/39
# ----------
# train Loss: 1.0790 Acc: 0.6119
# val Loss: 0.8724 Acc: 0.6803
#
# Epoch 4/39
# ----------
# train Loss: 0.9247 Acc: 0.6768
# val Loss: 0.6532 Acc: 0.7745
#
# Epoch 5/39
# ----------
# train Loss: 0.8845 Acc: 0.6932
# val Loss: 0.6723 Acc: 0.7757
#
# Epoch 6/39
# ----------
# train Loss: 0.7750 Acc: 0.7278
# val Loss: 0.6006 Acc: 0.8055
#
# Epoch 7/39
# ----------
# train Loss: 0.6961 Acc: 0.7624
# val Loss: 0.7070 Acc: 0.7571
#
# Epoch 8/39
# ----------
# train Loss: 0.6870 Acc: 0.7544
# val Loss: 0.5623 Acc: 0.8092
#
# Epoch 9/39
# ----------
# train Loss: 0.6381 Acc: 0.7788
# val Loss: 0.6546 Acc: 0.7646
#
# Epoch 10/39
# ----------
# train Loss: 0.5748 Acc: 0.8012
# val Loss: 0.6095 Acc: 0.8017
#
# Epoch 11/39
# ----------
# train Loss: 0.5831 Acc: 0.7964
# val Loss: 0.5056 Acc: 0.8278
#
# Epoch 12/39
# ----------
# train Loss: 0.5610 Acc: 0.7990
# val Loss: 0.5726 Acc: 0.8178
#
# Epoch 13/39
# ----------
# train Loss: 0.4949 Acc: 0.8288
# val Loss: 0.4882 Acc: 0.8389
#
# Epoch 14/39
# ----------
# train Loss: 0.4630 Acc: 0.8511
# val Loss: 0.6050 Acc: 0.8017
#
# Epoch 15/39
# ----------
# train Loss: 0.4179 Acc: 0.8602
# val Loss: 0.4267 Acc: 0.8637
#
# Epoch 16/39
# ----------
# train Loss: 0.3541 Acc: 0.8783
# val Loss: 0.8065 Acc: 0.7906
#
# Epoch 17/39
# ----------
# train Loss: 0.4070 Acc: 0.8554
# val Loss: 0.5861 Acc: 0.8092
#
# Epoch 18/39
# ----------
# train Loss: 0.3204 Acc: 0.8905
# val Loss: 0.6209 Acc: 0.8116
#
# Epoch 19/39
# ----------
# train Loss: 0.3081 Acc: 0.8947
# val Loss: 0.9110 Acc: 0.7460
#
# Epoch 20/39
# ----------
# train Loss: 0.2311 Acc: 0.9208
# val Loss: 0.4248 Acc: 0.8773
#
# Epoch 21/39
# ----------
# train Loss: 0.2038 Acc: 0.9320
# val Loss: 0.5365 Acc: 0.8575
#
# Epoch 22/39
# ----------
# train Loss: 0.2359 Acc: 0.9208
# val Loss: 0.4365 Acc: 0.8786
#
# Epoch 23/39
# ----------
# train Loss: 0.1990 Acc: 0.9314
# val Loss: 0.6037 Acc: 0.8327
#
# Epoch 24/39
# ----------
# train Loss: 0.1952 Acc: 0.9266
# val Loss: 0.4268 Acc: 0.8736
#
# Epoch 25/39
# ----------
# train Loss: 0.1849 Acc: 0.9325
# val Loss: 0.5857 Acc: 0.8600
#
# Epoch 26/39
# ----------
# train Loss: 0.1958 Acc: 0.9378
# val Loss: 0.4925 Acc: 0.8513
#
# Epoch 27/39
# ----------
# train Loss: 0.1298 Acc: 0.9601
# val Loss: 0.4609 Acc: 0.8761
#
# Epoch 28/39
# ----------
# train Loss: 0.1240 Acc: 0.9591
# val Loss: 0.7365 Acc: 0.8154
#
# Epoch 29/39
# ----------
# train Loss: 0.1561 Acc: 0.9463
# val Loss: 0.6928 Acc: 0.8401
#
# Epoch 30/39
# ----------
# train Loss: 0.1608 Acc: 0.9564
# val Loss: 0.6132 Acc: 0.8488
#
# Epoch 31/39
# ----------
# train Loss: 0.1137 Acc: 0.9623
# val Loss: 0.6080 Acc: 0.8414
#
# Epoch 32/39
# ----------
# train Loss: 0.1185 Acc: 0.9638
# val Loss: 0.5386 Acc: 0.8550
#
# Epoch 33/39
# ----------
# train Loss: 0.1097 Acc: 0.9628
# val Loss: 0.4746 Acc: 0.8823
#
# Epoch 34/39
# ----------
# train Loss: 0.1156 Acc: 0.9617
# val Loss: 0.5634 Acc: 0.8476
#
# Epoch 35/39
# ----------
# train Loss: 0.0678 Acc: 0.9777
# val Loss: 0.5967 Acc: 0.8439
#
# Epoch 36/39
# ----------
# train Loss: 0.0991 Acc: 0.9633
# val Loss: 0.5744 Acc: 0.8662
#
# Epoch 37/39
# ----------
# train Loss: 0.1103 Acc: 0.9628
# val Loss: 0.9101 Acc: 0.8079
#
# Epoch 38/39
# ----------
# train Loss: 0.1232 Acc: 0.9591
# val Loss: 0.5805 Acc: 0.8649
#
# Epoch 39/39
# ----------
# train Loss: 0.0767 Acc: 0.9750
# val Loss: 0.5615 Acc: 0.8724
#
# Training complete in 8m 28s
# Best val Acc: 0.882280

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses["train"], label="training loss")
ax1.plot(losses["val"], label="validation loss")
ax1.legend()

ax2.plot(hist["train"],label="training accuracy")
ax2.plot(hist["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# # 2. finetunning

# %%
def initialize_model(num_classes):
    # Resnet18 with pretrained weights 
    model = models.resnet18(pretrained=True) # Notice we are now loading the weights of a ResNet model trained on ImageNet
    #set_parameter_requires_grad(model, False)

    model.fc = nn.Sequential(
    nn.Dropout(0.5),
    nn.Linear(512, num_classes)
    )

    input_size = 512
    
    #input_size = 224
        
    return model, input_size


# Number of classes in the dataset
num_classes = 8

# Initialize the model
model_finetuning, input_size = initialize_model(num_classes)
optimizer_ft = optim.Adam(model_finetuning.parameters(), lr=0.001)

# YOUR CODE HERE!
# Send the model to GPU
model_finetuning = model_finetuning.to(device)
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40
#optimizer_ft = optim.Adam(model.fc.parameters(), lr=0.001)


# Train and evaluate
model_finetuning, hist_finetuning, losses_finetuning = train_model(model_finetuning, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/39
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 1.1076 Acc: 0.6252
# val Loss: 1.1343 Acc: 0.6642
#
# Epoch 1/39
# ----------
# train Loss: 0.7759 Acc: 0.7427
# val Loss: 0.4266 Acc: 0.8463
#
# Epoch 2/39
# ----------
# train Loss: 0.6272 Acc: 0.8001
# val Loss: 0.5881 Acc: 0.7968
#
# Epoch 3/39
# ----------
# train Loss: 0.5757 Acc: 0.8091
# val Loss: 0.3655 Acc: 0.8810
#
# Epoch 4/39
# ----------
# train Loss: 0.5067 Acc: 0.8304
# val Loss: 0.5024 Acc: 0.8550
#
# Epoch 5/39
# ----------
# train Loss: 0.4332 Acc: 0.8575
# val Loss: 0.3528 Acc: 0.8885
#
# Epoch 6/39
# ----------
# train Loss: 0.4055 Acc: 0.8602
# val Loss: 0.4736 Acc: 0.8439
#
# Epoch 7/39
# ----------
# train Loss: 0.3933 Acc: 0.8682
# val Loss: 0.4187 Acc: 0.8699
#
# Epoch 8/39
# ----------
# train Loss: 0.2895 Acc: 0.9027
# val Loss: 0.3152 Acc: 0.9009
#
# Epoch 9/39
# ----------
# train Loss: 0.2585 Acc: 0.9117
# val Loss: 0.3401 Acc: 0.8984
#
# Epoch 10/39
# ----------
# train Loss: 0.2288 Acc: 0.9261
# val Loss: 0.5171 Acc: 0.8587
#
# Epoch 11/39
# ----------
# train Loss: 0.3043 Acc: 0.8947
# val Loss: 0.4614 Acc: 0.8786
#
# Epoch 12/39
# ----------
# train Loss: 0.2111 Acc: 0.9282
# val Loss: 0.2986 Acc: 0.9083
#
# Epoch 13/39
# ----------
# train Loss: 0.2251 Acc: 0.9250
# val Loss: 0.3890 Acc: 0.8897
#
# Epoch 14/39
# ----------
# train Loss: 0.1939 Acc: 0.9431
# val Loss: 0.4369 Acc: 0.8910
#
# Epoch 15/39
# ----------
# train Loss: 0.2078 Acc: 0.9272
# val Loss: 0.3243 Acc: 0.8984
#
# Epoch 16/39
# ----------
# train Loss: 0.1590 Acc: 0.9484
# val Loss: 0.3780 Acc: 0.8971
#
# Epoch 17/39
# ----------
# train Loss: 0.1863 Acc: 0.9362
# val Loss: 0.4283 Acc: 0.8885
#
# Epoch 18/39
# ----------
# train Loss: 0.1045 Acc: 0.9676
# val Loss: 0.3268 Acc: 0.9120
#
# Epoch 19/39
# ----------
# train Loss: 0.1258 Acc: 0.9564
# val Loss: 0.3193 Acc: 0.9219
#
# Epoch 20/39
# ----------
# train Loss: 0.1636 Acc: 0.9463
# val Loss: 0.5267 Acc: 0.8674
#
# Epoch 21/39
# ----------
# train Loss: 0.2029 Acc: 0.9293
# val Loss: 0.4173 Acc: 0.8860
#
# Epoch 22/39
# ----------
# train Loss: 0.0984 Acc: 0.9697
# val Loss: 0.3999 Acc: 0.8959
#
# Epoch 23/39
# ----------
# train Loss: 0.0492 Acc: 0.9856
# val Loss: 0.2825 Acc: 0.9195
#
# Epoch 24/39
# ----------
# train Loss: 0.1092 Acc: 0.9660
# val Loss: 0.4193 Acc: 0.9046
#
# Epoch 25/39
# ----------
# train Loss: 0.1690 Acc: 0.9511
# val Loss: 0.5144 Acc: 0.8761
#
# Epoch 26/39
# ----------
# train Loss: 0.1455 Acc: 0.9569
# val Loss: 0.4338 Acc: 0.9046
#
# Epoch 27/39
# ----------
# train Loss: 0.0886 Acc: 0.9734
# val Loss: 0.5152 Acc: 0.8724
#
# Epoch 28/39
# ----------
# train Loss: 0.1172 Acc: 0.9612
# val Loss: 0.5618 Acc: 0.8587
#
# Epoch 29/39
# ----------
# train Loss: 0.0806 Acc: 0.9782
# val Loss: 0.3913 Acc: 0.9071
#
# Epoch 30/39
# ----------
# train Loss: 0.1008 Acc: 0.9665
# val Loss: 0.3939 Acc: 0.9021
#
# Epoch 31/39
# ----------
# train Loss: 0.1082 Acc: 0.9649
# val Loss: 0.4179 Acc: 0.9058
#
# Epoch 32/39
# ----------
# train Loss: 0.0854 Acc: 0.9782
# val Loss: 0.5304 Acc: 0.8922
#
# Epoch 33/39
# ----------
# train Loss: 0.0642 Acc: 0.9803
# val Loss: 0.3678 Acc: 0.9133
#
# Epoch 34/39
# ----------
# train Loss: 0.0526 Acc: 0.9846
# val Loss: 0.4831 Acc: 0.8922
#
# Epoch 35/39
# ----------
# train Loss: 0.0535 Acc: 0.9841
# val Loss: 0.3469 Acc: 0.9083
#
# Epoch 36/39
# ----------
# train Loss: 0.0582 Acc: 0.9835
# val Loss: 0.5662 Acc: 0.8563
#
# Epoch 37/39
# ----------
# train Loss: 0.1172 Acc: 0.9676
# val Loss: 0.6724 Acc: 0.8550
#
# Epoch 38/39
# ----------
# train Loss: 0.1260 Acc: 0.9585
# val Loss: 0.7132 Acc: 0.8748
#
# Epoch 39/39
# ----------
# train Loss: 0.1011 Acc: 0.9761
# val Loss: 0.5434 Acc: 0.8711
#
# Training complete in 8m 31s
# Best val Acc: 0.921933

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses_finetuning["train"], label="training loss")
ax1.plot(losses_finetuning["val"], label="validation loss")
ax1.legend()

ax2.plot(hist_finetuning["train"],label="training accuracy")
ax2.plot(hist_finetuning["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# # 3. feature extraction

# %%
def initialize_model(num_classes):
    # Resnet18 with pretrained weights 
    model = models.resnet18(pretrained=True) # Notice we are now loading the weights of a ResNet model trained on ImageNet
    set_parameter_requires_grad(model, True)

    model.fc = nn.Sequential(
    nn.Dropout(0.5),
    nn.Linear(512, num_classes)
    )
    
    input_size = 512
    
    #input_size = 224
        
    return model, input_size


# Number of classes in the dataset
num_classes = 8

# Initialize the model
model_feature_extraction, input_size = initialize_model(num_classes)

optimizer_ft = optim.Adam(model_feature_extraction.fc.parameters(), lr=0.001)

# YOUR CODE HERE!
# Send the model to GPU
model_feature_extraction = model_feature_extraction.to(device)
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40
#optimizer_ft = optim.Adam(model.fc.parameters(), lr=0.001)


# Train and evaluate
model_feature_extraction, hist_feature_extraction, losses_feature_extraction = train_model(model_feature_extraction, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/39
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 1.3939 Acc: 0.5029
# val Loss: 0.5287 Acc: 0.8798
#
# Epoch 1/39
# ----------
# train Loss: 0.8042 Acc: 0.7166
# val Loss: 0.3781 Acc: 0.8971
#
# Epoch 2/39
# ----------
# train Loss: 0.6991 Acc: 0.7656
# val Loss: 0.3282 Acc: 0.8872
#
# Epoch 3/39
# ----------
# train Loss: 0.6667 Acc: 0.7682
# val Loss: 0.3022 Acc: 0.9046
#
# Epoch 4/39
# ----------
# train Loss: 0.6081 Acc: 0.7916
# val Loss: 0.2711 Acc: 0.9244
#
# Epoch 5/39
# ----------
# train Loss: 0.6356 Acc: 0.7900
# val Loss: 0.2887 Acc: 0.9009
#
# Epoch 6/39
# ----------
# train Loss: 0.6020 Acc: 0.7863
# val Loss: 0.2499 Acc: 0.9182
#
# Epoch 7/39
# ----------
# train Loss: 0.6162 Acc: 0.7895
# val Loss: 0.2461 Acc: 0.9145
#
# Epoch 8/39
# ----------
# train Loss: 0.6207 Acc: 0.7847
# val Loss: 0.2663 Acc: 0.9095
#
# Epoch 9/39
# ----------
# train Loss: 0.5968 Acc: 0.7911
# val Loss: 0.2471 Acc: 0.9145
#
# Epoch 10/39
# ----------
# train Loss: 0.5680 Acc: 0.8033
# val Loss: 0.2496 Acc: 0.9108
#
# Epoch 11/39
# ----------
# train Loss: 0.6125 Acc: 0.7921
# val Loss: 0.2851 Acc: 0.9071
#
# Epoch 12/39
# ----------
# train Loss: 0.6065 Acc: 0.7831
# val Loss: 0.2583 Acc: 0.9157
#
# Epoch 13/39
# ----------
# train Loss: 0.6067 Acc: 0.7921
# val Loss: 0.2920 Acc: 0.8947
#
# Epoch 14/39
# ----------
# train Loss: 0.6036 Acc: 0.7836
# val Loss: 0.2739 Acc: 0.9046
#
# Epoch 15/39
# ----------
# train Loss: 0.6197 Acc: 0.7895
# val Loss: 0.2456 Acc: 0.9095
#
# Epoch 16/39
# ----------
# train Loss: 0.6113 Acc: 0.7842
# val Loss: 0.2417 Acc: 0.9157
#
# Epoch 17/39
# ----------
# train Loss: 0.5534 Acc: 0.8038
# val Loss: 0.2458 Acc: 0.9207
#
# Epoch 18/39
# ----------
# train Loss: 0.5275 Acc: 0.8161
# val Loss: 0.2386 Acc: 0.9071
#
# Epoch 19/39
# ----------
# train Loss: 0.5743 Acc: 0.7964
# val Loss: 0.2433 Acc: 0.9219
#
# Epoch 20/39
# ----------
# train Loss: 0.5970 Acc: 0.7996
# val Loss: 0.2443 Acc: 0.9095
#
# Epoch 21/39
# ----------
# train Loss: 0.5434 Acc: 0.8134
# val Loss: 0.2801 Acc: 0.8934
#
# Epoch 22/39
# ----------
# train Loss: 0.5551 Acc: 0.7985
# val Loss: 0.2224 Acc: 0.9232
#
# Epoch 23/39
# ----------
# train Loss: 0.5872 Acc: 0.8012
# val Loss: 0.2359 Acc: 0.9157
#
# Epoch 24/39
# ----------
# train Loss: 0.6083 Acc: 0.8012
# val Loss: 0.2469 Acc: 0.9071
#
# Epoch 25/39
# ----------
# train Loss: 0.5973 Acc: 0.7937
# val Loss: 0.2364 Acc: 0.9244
#
# Epoch 26/39
# ----------
# train Loss: 0.5690 Acc: 0.7948
# val Loss: 0.2321 Acc: 0.9033
#
# Epoch 27/39
# ----------
# train Loss: 0.6320 Acc: 0.7783
# val Loss: 0.2305 Acc: 0.9269
#
# Epoch 28/39
# ----------
# train Loss: 0.5715 Acc: 0.8065
# val Loss: 0.2328 Acc: 0.9157
#
# Epoch 29/39
# ----------
# train Loss: 0.5871 Acc: 0.7996
# val Loss: 0.2633 Acc: 0.9071
#
# Epoch 30/39
# ----------
# train Loss: 0.6170 Acc: 0.7836
# val Loss: 0.2455 Acc: 0.9071
#
# Epoch 31/39
# ----------
# train Loss: 0.6132 Acc: 0.7964
# val Loss: 0.2449 Acc: 0.9083
#
# Epoch 32/39
# ----------
# train Loss: 0.6041 Acc: 0.7959
# val Loss: 0.2312 Acc: 0.9108
#
# Epoch 33/39
# ----------
# train Loss: 0.6113 Acc: 0.7921
# val Loss: 0.2311 Acc: 0.9120
#
# Epoch 34/39
# ----------
# train Loss: 0.5746 Acc: 0.7932
# val Loss: 0.2358 Acc: 0.9120
#
# Epoch 35/39
# ----------
# train Loss: 0.6350 Acc: 0.7911
# val Loss: 0.2227 Acc: 0.9232
#
# Epoch 36/39
# ----------
# train Loss: 0.5863 Acc: 0.8001
# val Loss: 0.2301 Acc: 0.9219
#
# Epoch 37/39
# ----------
# train Loss: 0.6036 Acc: 0.7895
# val Loss: 0.2348 Acc: 0.9207
#
# Epoch 38/39
# ----------
# train Loss: 0.5892 Acc: 0.8086
# val Loss: 0.2215 Acc: 0.9145
#
# Epoch 39/39
# ----------
# train Loss: 0.6188 Acc: 0.7932
# val Loss: 0.2392 Acc: 0.9157
#
# Training complete in 6m 32s
# Best val Acc: 0.926890

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses_feature_extraction["train"], label="training loss")
ax1.plot(losses_feature_extraction["val"], label="validation loss")
ax1.legend()

ax2.plot(hist_feature_extraction["train"],label="training accuracy")
ax2.plot(hist_feature_extraction["val"],label="val accuracy")
ax2.legend()

plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(18, 10))

#scratch
axs[0, 0].plot(losses["train"], label='training loss')
axs[0, 0].plot(losses["val"], label='validation loss')
axs[0, 0].set_title('Scratch loss')
axs[0, 0].legend()

axs[0, 1].plot(hist["train"], label='training loss')
axs[0, 1].plot(hist["val"], label='validation loss')
axs[0, 1].set_title('Scratch accuracy')
axs[0, 1].legend()

#feature extraction
axs[1, 0].plot(losses_feature_extraction["train"], label='training loss')
axs[1, 0].plot(losses_feature_extraction["val"], label='validation loss')
axs[1, 0].set_title('Feature extraction loss')
axs[1, 0].legend()

axs[1, 1].plot(hist_feature_extraction['train'], label='training loss')
axs[1, 1].plot(hist_feature_extraction['val'], label='validation loss')
axs[1, 1].set_title('Feature extraction accuracy')
axs[1, 1].legend()

#finetuning
axs[2, 0].plot(losses_finetuning["train"], label='training loss')
axs[2, 0].plot(losses_finetuning["val"], label='validation loss')
axs[2, 0].set_title('Finetunning loss')
axs[2, 0].legend()

axs[2, 1].plot(hist_finetuning['train'], label='training loss')
axs[2, 1].plot(hist_finetuning['val'], label='validation loss')
axs[2, 1].set_title('Finetuning accuracy')
axs[2, 1].legend()

"""
for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
"""
# Out:
# "\nfor ax in axs.flat:\n    ax.set(xlabel='x-label', ylabel='y-label')\n\n# Hide x labels and tick labels for top plots and y ticks for right plots.\nfor ax in axs.flat:\n    ax.label_outer()\n"

# %% [markdown]
# E) Choose a diferent CNN architecture from the [`torchvision models`](https://pytorch.org/docs/stable/torchvision/models.html) module and try to beat the best model obtained in the previous exercise. You can also change some hyper-parameters if you think it is going to help (batch size, learning rate, optimizer, etc.). Justify your choice, even if you don't get better accuracy explain why you thought it was promising.

# %%
# YOUR CODE HERE!
